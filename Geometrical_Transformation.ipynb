# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import pandas as pd
import matplotlib as plt
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d4be7b70-f0a7-40d0-91c2-08d237f9ddec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4be7b70-f0a7-40d0-91c2-08d237f9ddec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aloevera.jpg to aloevera.jpg

# %% [markdown]
# **Resize Image**

# %%
img = cv2.imread('aloevera.jpg')
cv2_imshow(img)
height, width = img.shape[:2]
res = cv2.resize(img,(2*width, 2*height), interpolation = cv2.INTER_CUBIC)
cv2_imshow(res)
print(h,h1)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F30694A38D0>
# <PIL.Image.Image image mode=RGB size=550x366 at 0x7F30694A34A8>
# None None

# %%
img.shape
# Out:
# (183, 275, 3)

# %% [markdown]
# **Rotation**

# %%
img = cv2.imread('aloevera.jpg')
rows,cols,cha = img.shape
M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)
dst = cv2.warpAffine(img,M,(cols,rows))
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F306ADCF240>

# %% [markdown]
# Translation

# %%
M = np.float32([[1,0,100],[0,1,50]])
dst = cv2.warpAffine(img,M,(cols,rows))
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F306ADCFEF0>

# %% [markdown]
# Cropping

# %%
img1 = cv2.imread('aloevera.jpg')
crop_img = img1[70:170, 70:170]
cv2_imshow(crop_img)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F306ADCF358>
